# %% [markdown]
# ## Imporation of the dataset

# %%
import os
from glob import glob
import matplotlib.pyplot as plt
import rasterio as rio
from rasterio.plot import plotting_extent
import geopandas as gpd
import earthpy as et
import earthpy.spatial as es
import earthpy.plot as ep

# %%
#import rasterio
#from rasterio import mask
import folium
from osgeo import gdal
import georaster as gr
import pandas as pd
import numpy as np

# %%
#Importatio of the data reprojected

data1= gdal.Open("rpj/iowaReprj.tif")

# %%
array= data1.GetRasterBand(1).ReadAsArray()

# %%
plt.figure(figsize=(9, 7))
ep.hist(array, title="Band 1")
plt.show()

# %% [markdown]
# The plot above represent the band.

# %%
import rasterio
src = rasterio.open("rpj/iowaReprj.tif")
plt.figure(figsize=(10, 6))
plt.imshow(src.read(1), cmap='Greens_r')
plt.show(block=False)

# %%
from rasterio.plot import show
plt.figure(figsize=(10, 6))
show(src)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(10, 6))
show((src, 1), transform=src.transform, cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
fig, ax = plt.subplots(1, figsize=(12, 12))
show((src, 1), ax=ax, contour=True, contour_label_kws={})
plt.show(block=False)

# %%
plt.figure(figsize=(12, 8))
from rasterio.plot import show_hist
show_hist(
    src, bins=50, lw=0.0, stacked=False, alpha=0.3,
   histtype='stepfilled', title="Histogram of a raster")

# %%
fig, (axrgb, axhist) = plt.subplots(1, 2, figsize=(14,7))
show((src), cmap='Greys_r', contour=True, ax=axrgb)
show_hist(src, bins=50, histtype='stepfilled',
          lw=0.0, stacked=False, alpha=0.3, ax=axhist)
plt.show()
